# %%
# python detect_mask_video.py

# import the necessary packages
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from imutils.video import VideoStream
import numpy as np
import argparse
import imutils
import time
import cv2
import os
# Out:
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# to capture the image 
def detect_and_predict_mask(frame,faceNet,maskNet):
    # to get the dimension of the frame and to construct the blob
    (h,w)= frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame,1.0,(300,300),
                                 (104.0,177.0,123.0))
    
    #pass the blob through model and detect the face using faceNet
    faceNet.setInput(blob)
    detections = faceNet.forward()
    
    #initialize the list of face and the corresponding locatins and the list of predicitons from our face mask model
    
    faces =[]
    locs =[]
    preds =[]
    
    # loop over detections
    for i in range(0,detections.shape[2]):
        # extract the probability
        confidence = detections[0,0,i,2]
        
        #filter out weak detections by ensuring the confidence/probability value
        # (i.e) the confidence value is greater than the min conf value
        
        if confidence>args['confidence']:
            #compute the x and y coordinates of bounding box 
            
            box = detections[0,0,i,3:7]*np.array([w,h,w,h])
            (startX,startY,endX,endY)=box.astype("int")
            
            #ensure the box falls within the face dim
            (startX,startY) =(max(0,startX),max(0,startY))
            (endX,endY) = (min(w-1,endX),min(h-1,endY))
            face = frame[startY:endY,startX:endX]

            # Debugging statements
            print(f"Detection {i}: confidence={confidence}")
            print(f"Bounding box: startX={startX}, startY={startY}, endX={endX}, endY={endY}")
            print(f"Face shape: {face.shape}")

            if face.size == 0:
                print("Empty face image detected, skipping...")
                continue
            
            #extract the face ROI, convert it to BGR to RGB channel ordering, resize it to 224x224, and preprocess it
            # face = frame[startY:endY,startX:endX]
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face,(224,224))
            face = img_to_array(face)
            face = preprocess_input(face)
            
            # add the face and bounding box to the respective list
            faces.append(face)
            locs.append((startX,startY,endX,endY))
            
    # to give a condition to predict atleast one face was detected
    if len(faces)>0:
# for faster inference we'll make batch predictions on *all*
# faces at the same time rather than one-by-one predictions
# in the above `for` loop
        faces = np.array(faces,dtype ='float32')
        preds = maskNet.predict(faces,batch_size = 32)
        
    return (locs,preds)

# %%
# construct the argument parser and parse the arguments
# Construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-f", "--face", type=str, default="face_detector", help="path to face detector model directory")
# ap.add_argument("-m", "--model", type=str, default="mask_detector.h5", help="path to trained face mask detector model")
# ap.add_argument("-c", "--confidence", type=float, default=0.5, help="minimum probability to filter weak detections")
# args = vars(ap.parse_args())

args = {
    "face": "face_detector",
    "model": "mask_detector.h5",
    "confidence": 0.5
}


# Construct the absolute paths to the model files
project_root = os.path.abspath(os.path.dirname(r"S:\AI_RELATED\AI_PROJECTS\Face_Mask_Detection\face_detector"))
face_detector_directory = os.path.join(project_root, 'face_detector')
prototxtPath = os.path.join(face_detector_directory, "deploy.prototxt")
weightsPath = os.path.join(face_detector_directory, "res10_300x300_ssd_iter_140000.caffemodel")

print(f"Prototxt path: {prototxtPath}")
print(f"Weights path: {weightsPath}")

if not os.path.exists(prototxtPath):
    print(f"Error: {prototxtPath} not found.")
if not os.path.exists(weightsPath):
    print(f"Error: {weightsPath} not found.")

faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)
# Load the face mask detector model
from tensorflow.keras.models import load_model
maskNet = load_model(args["model"])
# Out:
# Prototxt path: S:\AI_RELATED\AI_PROJECTS\Face_Mask_Detection\face_detector\deploy.prototxt
# Weights path: S:\AI_RELATED\AI_PROJECTS\Face_Mask_Detection\face_detector\res10_300x300_ssd_iter_140000.caffemodel
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\facemask\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Load the face mask detector model from disk
print("[INFO] loading face mask detector model...")
maskNet = load_model(args["model"])
# Out:
# [INFO] loading face mask detector model...

# %%
# pip install pyttsx3==2.90

# %%
# initialize the video stream and allow the camera sensor to warm up
print("[INFO] starting video stream...")
vs = VideoStream(src=0).start()
time.sleep(2.0)
# Out:
# [INFO] starting video stream...

# %%
import pyttsx3

# Initialize the TTS engine
engine = pyttsx3.init()
engine.setProperty('rate', 150)  # Speed of speech
engine.setProperty('volume', 1.0)  # Volume (0.0 to 1.0)

# %% [markdown]
# # With Voice

# %%
import pyttsx3

# Initialize TTS engine
engine = pyttsx3.init()
engine.setProperty('rate', 150)
engine.setProperty('volume', 1.0)

# Track last spoken label
previous_label = None
cooldown_counter = 0  # Helps avoid repeating voice messages

# Start looping through video frames
while True:
    # Read and resize frame
    frame = vs.read()
    frame = imutils.resize(frame, width=400)

    # Detect faces and predict mask usage
    (locs, preds) = detect_and_predict_mask(frame, faceNet, maskNet)

    for (box, pred) in zip(locs, preds):
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred

        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)
        msg = "Mask: You are allowed" if label == "Mask" else "No Mask: You are not allowed"

        # Draw rectangle and label
        cv2.putText(frame, msg, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

        # Text-to-speech logic
        if label != previous_label or cooldown_counter > 30:
            engine.say(msg)
            engine.runAndWait()
            previous_label = label
            cooldown_counter = 0
        else:
            cooldown_counter += 1

    # Show the frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF

    # Press 'q' to quit
    if key == ord("q"):
        break

# Cleanup
cv2.destroyAllWindows()
vs.stop()  # use .stop() instead of .release() for VideoStream
# Out:
# Detection 0: confidence=0.9702900648117065
# Bounding box: startX=175, startY=126, endX=265, endY=244
# Face shape: (118, 90, 3)
# Detection 0: confidence=0.9596977829933167
# Bounding box: startX=171, startY=125, endX=261, endY=244
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9718539714813232
# Bounding box: startX=169, startY=126, endX=262, endY=244
# Face shape: (118, 93, 3)
# Detection 0: confidence=0.9600735306739807
# Bounding box: startX=171, startY=126, endX=261, endY=245
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9642112255096436
# Bounding box: startX=171, startY=126, endX=262, endY=245
# Face shape: (119, 91, 3)
# Detection 0: confidence=0.95664381980896
# Bounding box: startX=170, startY=125, endX=262, endY=244
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.959155797958374
# Bounding box: startX=170, startY=125, endX=262, endY=244
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.9667173027992249
# Bounding box: startX=170, startY=126, endX=262, endY=244
# Face shape: (118, 92, 3)
# Detection 0: confidence=0.9590690732002258
# Bounding box: startX=170, startY=125, endX=262, endY=244
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.9632551074028015
# Bounding box: startX=170, startY=125, endX=261, endY=244
# Face shape: (119, 91, 3)
# Detection 0: confidence=0.9579288959503174
# Bounding box: startX=171, startY=125, endX=260, endY=243
# Face shape: (118, 89, 3)
# Detection 0: confidence=0.9585751295089722
# Bounding box: startX=170, startY=125, endX=259, endY=242
# Face shape: (117, 89, 3)
# Detection 0: confidence=0.9486722946166992
# Bounding box: startX=170, startY=125, endX=259, endY=241
# Face shape: (116, 89, 3)
# Detection 0: confidence=0.9461653232574463
# Bounding box: startX=171, startY=126, endX=257, endY=241
# Face shape: (115, 86, 3)
# Detection 0: confidence=0.9567302465438843
# Bounding box: startX=168, startY=123, endX=255, endY=240
# Face shape: (117, 87, 3)
# Detection 0: confidence=0.9626527428627014
# Bounding box: startX=167, startY=123, endX=254, endY=241
# Face shape: (118, 87, 3)
# Detection 0: confidence=0.9705857634544373
# Bounding box: startX=168, startY=124, endX=254, endY=240
# Face shape: (116, 86, 3)
# Detection 0: confidence=0.968819260597229
# Bounding box: startX=168, startY=124, endX=254, endY=240
# Face shape: (116, 86, 3)
# Detection 0: confidence=0.9750092625617981
# Bounding box: startX=168, startY=124, endX=254, endY=240
# Face shape: (116, 86, 3)
# Detection 0: confidence=0.9737446904182434
# Bounding box: startX=168, startY=124, endX=253, endY=240
# Face shape: (116, 85, 3)
# Detection 0: confidence=0.9720495939254761
# Bounding box: startX=165, startY=124, endX=253, endY=240
# Face shape: (116, 88, 3)
# Detection 0: confidence=0.9651982188224792
# Bounding box: startX=163, startY=125, endX=252, endY=241
# Face shape: (116, 89, 3)
# Detection 0: confidence=0.9655289053916931
# Bounding box: startX=162, startY=126, endX=251, endY=242
# Face shape: (116, 89, 3)
# Detection 0: confidence=0.9543594717979431
# Bounding box: startX=161, startY=127, endX=250, endY=243
# Face shape: (116, 89, 3)
# Detection 0: confidence=0.9608898758888245
# Bounding box: startX=162, startY=128, endX=250, endY=243
# Face shape: (115, 88, 3)
# Detection 0: confidence=0.9720425009727478
# Bounding box: startX=161, startY=129, endX=250, endY=242
# Face shape: (113, 89, 3)
# Detection 0: confidence=0.956074595451355
# Bounding box: startX=159, startY=127, endX=250, endY=244
# Face shape: (117, 91, 3)
# Detection 0: confidence=0.9736788272857666
# Bounding box: startX=161, startY=127, endX=250, endY=243
# Face shape: (116, 89, 3)
# Detection 0: confidence=0.9643529057502747
# Bounding box: startX=163, startY=127, endX=252, endY=242
# Face shape: (115, 89, 3)
# Detection 0: confidence=0.9526926279067993
# Bounding box: startX=165, startY=126, endX=252, endY=242
# Face shape: (116, 87, 3)
# Detection 0: confidence=0.9634075164794922
# Bounding box: startX=167, startY=123, endX=252, endY=241
# Face shape: (118, 85, 3)
# Detection 0: confidence=0.9778620004653931
# Bounding box: startX=169, startY=120, endX=252, endY=236
# Face shape: (116, 83, 3)
# Detection 0: confidence=0.9748898148536682
# Bounding box: startX=170, startY=117, endX=252, endY=227
# Face shape: (110, 82, 3)
# Detection 0: confidence=0.9864093065261841
# Bounding box: startX=177, startY=116, endX=260, endY=223
# Face shape: (107, 83, 3)
# Detection 0: confidence=0.9901643395423889
# Bounding box: startX=176, startY=116, endX=257, endY=219
# Face shape: (103, 81, 3)
# Detection 0: confidence=0.9955442547798157
# Bounding box: startX=172, startY=116, endX=251, endY=215
# Face shape: (99, 79, 3)
# Detection 0: confidence=0.9974712133407593
# Bounding box: startX=173, startY=117, endX=249, endY=212
# Face shape: (95, 76, 3)
# Detection 0: confidence=0.9982045888900757
# Bounding box: startX=175, startY=117, endX=248, endY=210
# Face shape: (93, 73, 3)
# Detection 0: confidence=0.9980883002281189
# Bounding box: startX=174, startY=117, endX=248, endY=210
# Face shape: (93, 74, 3)
# Detection 0: confidence=0.9981085062026978
# Bounding box: startX=176, startY=116, endX=248, endY=210
# Face shape: (94, 72, 3)
# Detection 0: confidence=0.9970113039016724
# Bounding box: startX=177, startY=116, endX=250, endY=209
# Face shape: (93, 73, 3)
# Detection 0: confidence=0.9751673340797424
# Bounding box: startX=176, startY=117, endX=253, endY=207
# Face shape: (90, 77, 3)
# Detection 0: confidence=0.5771508812904358
# Bounding box: startX=174, startY=113, endX=258, endY=204
# Face shape: (91, 84, 3)
# Detection 0: confidence=0.683667004108429
# Bounding box: startX=174, startY=119, endX=257, endY=216
# Face shape: (97, 83, 3)
# Detection 0: confidence=0.8460201621055603
# Bounding box: startX=174, startY=118, endX=260, endY=223
# Face shape: (105, 86, 3)
# Detection 0: confidence=0.7944096326828003
# Bounding box: startX=173, startY=115, endX=261, endY=223
# Face shape: (108, 88, 3)
# Detection 0: confidence=0.8343268036842346
# Bounding box: startX=174, startY=116, endX=262, endY=222
# Face shape: (106, 88, 3)
# Detection 0: confidence=0.7448039650917053
# Bounding box: startX=177, startY=117, endX=263, endY=228
# Face shape: (111, 86, 3)
# Detection 0: confidence=0.730719804763794
# Bounding box: startX=178, startY=117, endX=263, endY=228
# Face shape: (111, 85, 3)
# Detection 0: confidence=0.7572411298751831
# Bounding box: startX=178, startY=118, endX=262, endY=228
# Face shape: (110, 84, 3)
# Detection 0: confidence=0.7620803713798523
# Bounding box: startX=176, startY=117, endX=262, endY=227
# Face shape: (110, 86, 3)
# Detection 0: confidence=0.7762431502342224
# Bounding box: startX=177, startY=117, endX=263, endY=228
# Face shape: (111, 86, 3)
# Detection 0: confidence=0.6324563026428223
# Bounding box: startX=177, startY=119, endX=262, endY=227
# Face shape: (108, 85, 3)
# Detection 0: confidence=0.7063742280006409
# Bounding box: startX=177, startY=119, endX=263, endY=227
# Face shape: (108, 86, 3)
# Detection 0: confidence=0.7881838083267212
# Bounding box: startX=177, startY=119, endX=263, endY=225
# Face shape: (106, 86, 3)
# Detection 0: confidence=0.7180888652801514
# Bounding box: startX=177, startY=119, endX=263, endY=226
# Face shape: (107, 86, 3)
# Detection 0: confidence=0.7633624076843262
# Bounding box: startX=177, startY=118, endX=263, endY=227
# Face shape: (109, 86, 3)
# Detection 0: confidence=0.7682839035987854
# Bounding box: startX=177, startY=119, endX=262, endY=226
# Face shape: (107, 85, 3)
# Detection 0: confidence=0.8103569746017456
# Bounding box: startX=177, startY=118, endX=263, endY=225
# Face shape: (107, 86, 3)
# Detection 0: confidence=0.8146004676818848
# Bounding box: startX=176, startY=118, endX=262, endY=224
# Face shape: (106, 86, 3)
# Detection 0: confidence=0.7887760996818542
# Bounding box: startX=176, startY=119, endX=262, endY=226
# Face shape: (107, 86, 3)
# Detection 0: confidence=0.7658127546310425
# Bounding box: startX=174, startY=118, endX=261, endY=227
# Face shape: (109, 87, 3)
# Detection 0: confidence=0.6190065741539001
# Bounding box: startX=176, startY=118, endX=263, endY=229
# Face shape: (111, 87, 3)
# Detection 0: confidence=0.7318828105926514
# Bounding box: startX=177, startY=119, endX=268, endY=225
# Face shape: (106, 91, 3)
# Detection 0: confidence=0.9513704180717468
# Bounding box: startX=179, startY=118, endX=272, endY=246
# Face shape: (128, 93, 3)
# Detection 0: confidence=0.9492813944816589
# Bounding box: startX=177, startY=119, endX=272, endY=248
# Face shape: (129, 95, 3)
# Detection 0: confidence=0.9601624608039856
# Bounding box: startX=175, startY=120, endX=272, endY=249
# Face shape: (129, 97, 3)
# Detection 0: confidence=0.9708477258682251
# Bounding box: startX=174, startY=121, endX=271, endY=250
# Face shape: (129, 97, 3)
# Detection 0: confidence=0.9362245202064514
# Bounding box: startX=174, startY=120, endX=270, endY=247
# Face shape: (127, 96, 3)
# Detection 0: confidence=0.9169260263442993
# Bounding box: startX=174, startY=120, endX=270, endY=246
# Face shape: (126, 96, 3)
# Detection 0: confidence=0.9036173820495605
# Bounding box: startX=175, startY=120, endX=270, endY=247
# Face shape: (127, 95, 3)
# Detection 0: confidence=0.897260308265686
# Bounding box: startX=174, startY=120, endX=270, endY=247
# Face shape: (127, 96, 3)
# Detection 0: confidence=0.9237420558929443
# Bounding box: startX=174, startY=119, endX=270, endY=248
# Face shape: (129, 96, 3)
# Detection 0: confidence=0.9553943872451782
# Bounding box: startX=174, startY=120, endX=270, endY=247
# Face shape: (127, 96, 3)
# Detection 0: confidence=0.9263185262680054
# Bounding box: startX=175, startY=120, endX=269, endY=248
# Face shape: (128, 94, 3)
# Detection 0: confidence=0.9424062967300415
# Bounding box: startX=175, startY=119, endX=269, endY=247
# Face shape: (128, 94, 3)
# Detection 0: confidence=0.5389139652252197
# Bounding box: startX=180, startY=158, endX=235, endY=219
# Face shape: (61, 55, 3)
# Detection 0: confidence=0.7241178750991821
# Bounding box: startX=173, startY=154, endX=228, endY=226
# Face shape: (72, 55, 3)
# Detection 0: confidence=0.9595626592636108
# Bounding box: startX=176, startY=150, endX=229, endY=219
# Face shape: (69, 53, 3)
# Detection 0: confidence=0.9919754862785339
# Bounding box: startX=172, startY=114, endX=261, endY=231
# Face shape: (117, 89, 3)
# Detection 0: confidence=0.9926653504371643
# Bounding box: startX=172, startY=116, endX=261, endY=230
# Face shape: (114, 89, 3)
# Detection 0: confidence=0.9912756681442261
# Bounding box: startX=173, startY=117, endX=259, endY=228
# Face shape: (111, 86, 3)
# Detection 0: confidence=0.9882717728614807
# Bounding box: startX=173, startY=118, endX=257, endY=227
# Face shape: (109, 84, 3)
# Detection 0: confidence=0.9873716831207275
# Bounding box: startX=173, startY=116, endX=259, endY=228
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9905920624732971
# Bounding box: startX=174, startY=118, endX=261, endY=228
# Face shape: (110, 87, 3)
# Detection 0: confidence=0.9896739721298218
# Bounding box: startX=174, startY=117, endX=261, endY=229
# Face shape: (112, 87, 3)
# Detection 0: confidence=0.9874300360679626
# Bounding box: startX=173, startY=117, endX=259, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9879156351089478
# Bounding box: startX=172, startY=117, endX=259, endY=229
# Face shape: (112, 87, 3)
# Detection 0: confidence=0.9864566326141357
# Bounding box: startX=172, startY=117, endX=259, endY=230
# Face shape: (113, 87, 3)
# Detection 0: confidence=0.9880911111831665
# Bounding box: startX=172, startY=117, endX=258, endY=230
# Face shape: (113, 86, 3)
# Detection 0: confidence=0.9894617199897766
# Bounding box: startX=172, startY=117, endX=258, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9906312823295593
# Bounding box: startX=172, startY=117, endX=258, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9903762936592102
# Bounding box: startX=172, startY=117, endX=258, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9914032816886902
# Bounding box: startX=171, startY=117, endX=257, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9887725710868835
# Bounding box: startX=171, startY=117, endX=257, endY=230
# Face shape: (113, 86, 3)
# Detection 0: confidence=0.991181492805481
# Bounding box: startX=171, startY=117, endX=257, endY=229
# Face shape: (112, 86, 3)
# Detection 0: confidence=0.9894647598266602
# Bounding box: startX=172, startY=117, endX=257, endY=230
# Face shape: (113, 85, 3)
# Detection 0: confidence=0.983449399471283
# Bounding box: startX=170, startY=118, endX=255, endY=230
# Face shape: (112, 85, 3)
# Detection 0: confidence=0.9775387644767761
# Bounding box: startX=169, startY=119, endX=253, endY=233
# Face shape: (114, 84, 3)
# Detection 0: confidence=0.9745761752128601
# Bounding box: startX=169, startY=119, endX=253, endY=235
# Face shape: (116, 84, 3)
# Detection 0: confidence=0.980154275894165
# Bounding box: startX=169, startY=119, endX=253, endY=235
# Face shape: (116, 84, 3)
# Detection 0: confidence=0.9810875058174133
# Bounding box: startX=169, startY=119, endX=253, endY=235
# Face shape: (116, 84, 3)
# Detection 0: confidence=0.9835187196731567
# Bounding box: startX=169, startY=119, endX=253, endY=234
# Face shape: (115, 84, 3)
# Detection 0: confidence=0.9774068593978882
# Bounding box: startX=169, startY=119, endX=253, endY=235
# Face shape: (116, 84, 3)
# Detection 0: confidence=0.980148196220398
# Bounding box: startX=169, startY=119, endX=253, endY=235
# Face shape: (116, 84, 3)
# Detection 0: confidence=0.9808999300003052
# Bounding box: startX=169, startY=120, endX=253, endY=235
# Face shape: (115, 84, 3)
# Detection 0: confidence=0.9813475608825684
# Bounding box: startX=169, startY=118, endX=253, endY=233
# Face shape: (115, 84, 3)
# Detection 0: confidence=0.9820143580436707
# Bounding box: startX=170, startY=119, endX=253, endY=233
# Face shape: (114, 83, 3)
# Detection 0: confidence=0.9774945378303528
# Bounding box: startX=169, startY=117, endX=253, endY=234
# Face shape: (117, 84, 3)
# Detection 0: confidence=0.9838813543319702
# Bounding box: startX=170, startY=118, endX=253, endY=233
# Face shape: (115, 83, 3)
# Detection 0: confidence=0.9837784767150879
# Bounding box: startX=169, startY=118, endX=253, endY=233
# Face shape: (115, 84, 3)
# Detection 0: confidence=0.97245854139328
# Bounding box: startX=160, startY=121, endX=251, endY=239
# Face shape: (118, 91, 3)
# Detection 0: confidence=0.9778359532356262
# Bounding box: startX=160, startY=121, endX=250, endY=238
# Face shape: (117, 90, 3)
# Detection 0: confidence=0.9780413508415222
# Bounding box: startX=161, startY=121, endX=250, endY=238
# Face shape: (117, 89, 3)
# Detection 0: confidence=0.9732015132904053
# Bounding box: startX=160, startY=121, endX=251, endY=239
# Face shape: (118, 91, 3)
# Detection 0: confidence=0.978164553642273
# Bounding box: startX=161, startY=121, endX=251, endY=239
# Face shape: (118, 90, 3)
# Detection 0: confidence=0.9789997339248657
# Bounding box: startX=160, startY=122, endX=250, endY=239
# Face shape: (117, 90, 3)
# Detection 0: confidence=0.9744797348976135
# Bounding box: startX=159, startY=122, endX=250, endY=239
# Face shape: (117, 91, 3)
# Detection 0: confidence=0.9711304306983948
# Bounding box: startX=158, startY=122, endX=250, endY=239
# Face shape: (117, 92, 3)
# Detection 0: confidence=0.9747378826141357
# Bounding box: startX=159, startY=123, endX=250, endY=239
# Face shape: (116, 91, 3)
# Detection 0: confidence=0.976942777633667
# Bounding box: startX=159, startY=123, endX=250, endY=239
# Face shape: (116, 91, 3)
# Detection 0: confidence=0.9566548466682434
# Bounding box: startX=158, startY=117, endX=250, endY=242
# Face shape: (125, 92, 3)
# Detection 0: confidence=0.9600453972816467
# Bounding box: startX=158, startY=118, endX=249, endY=242
# Face shape: (124, 91, 3)
# Detection 0: confidence=0.967172384262085
# Bounding box: startX=158, startY=117, endX=249, endY=242
# Face shape: (125, 91, 3)
# Detection 0: confidence=0.9636982679367065
# Bounding box: startX=158, startY=116, endX=250, endY=242
# Face shape: (126, 92, 3)
# Detection 0: confidence=0.95107501745224
# Bounding box: startX=160, startY=116, endX=249, endY=241
# Face shape: (125, 89, 3)
# Detection 0: confidence=0.958825945854187
# Bounding box: startX=160, startY=114, endX=250, endY=242
# Face shape: (128, 90, 3)
# Detection 0: confidence=0.9621883034706116
# Bounding box: startX=160, startY=114, endX=250, endY=241
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9659603238105774
# Bounding box: startX=160, startY=114, endX=250, endY=241
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9645175933837891
# Bounding box: startX=159, startY=115, endX=250, endY=241
# Face shape: (126, 91, 3)
# Detection 0: confidence=0.9734559655189514
# Bounding box: startX=159, startY=115, endX=249, endY=242
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9592761397361755
# Bounding box: startX=160, startY=115, endX=250, endY=242
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9732427597045898
# Bounding box: startX=159, startY=115, endX=249, endY=242
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9693525433540344
# Bounding box: startX=159, startY=116, endX=249, endY=243
# Face shape: (127, 90, 3)
# Detection 0: confidence=0.9664467573165894
# Bounding box: startX=159, startY=115, endX=249, endY=241
# Face shape: (126, 90, 3)
# Detection 0: confidence=0.9642346501350403
# Bounding box: startX=160, startY=115, endX=250, endY=241
# Face shape: (126, 90, 3)
# Detection 0: confidence=0.9667760133743286
# Bounding box: startX=159, startY=114, endX=250, endY=241
# Face shape: (127, 91, 3)
# Detection 0: confidence=0.9779900312423706
# Bounding box: startX=158, startY=115, endX=249, endY=240
# Face shape: (125, 91, 3)
# Detection 0: confidence=0.9801265597343445
# Bounding box: startX=157, startY=113, endX=249, endY=240
# Face shape: (127, 92, 3)
# Detection 0: confidence=0.9857017993927002
# Bounding box: startX=157, startY=114, endX=247, endY=240
# Face shape: (126, 90, 3)
# Detection 0: confidence=0.9900221228599548
# Bounding box: startX=154, startY=116, endX=246, endY=242
# Face shape: (126, 92, 3)
# Detection 0: confidence=0.990465521812439
# Bounding box: startX=154, startY=117, endX=247, endY=240
# Face shape: (123, 93, 3)
# Detection 0: confidence=0.987483024597168
# Bounding box: startX=155, startY=118, endX=246, endY=240
# Face shape: (122, 91, 3)
# Detection 0: confidence=0.957580029964447
# Bounding box: startX=158, startY=120, endX=248, endY=243
# Face shape: (123, 90, 3)
# Detection 0: confidence=0.9610193371772766
# Bounding box: startX=156, startY=124, endX=250, endY=240
# Face shape: (116, 94, 3)
# Detection 0: confidence=0.9572597742080688
# Bounding box: startX=159, startY=119, endX=247, endY=242
# Face shape: (123, 88, 3)
# Detection 0: confidence=0.9670082330703735
# Bounding box: startX=156, startY=123, endX=249, endY=239
# Face shape: (116, 93, 3)
# Detection 0: confidence=0.9647884368896484
# Bounding box: startX=156, startY=123, endX=249, endY=240
# Face shape: (117, 93, 3)
# Detection 0: confidence=0.9636600613594055
# Bounding box: startX=159, startY=117, endX=249, endY=240
# Face shape: (123, 90, 3)
# Detection 0: confidence=0.9626383781433105
# Bounding box: startX=159, startY=116, endX=249, endY=241
# Face shape: (125, 90, 3)
# Detection 0: confidence=0.9612722992897034
# Bounding box: startX=159, startY=116, endX=248, endY=240
# Face shape: (124, 89, 3)
# Detection 0: confidence=0.9624882936477661
# Bounding box: startX=159, startY=114, endX=249, endY=239
# Face shape: (125, 90, 3)
# Detection 0: confidence=0.9762198328971863
# Bounding box: startX=158, startY=115, endX=249, endY=242
# Face shape: (127, 91, 3)
# Detection 0: confidence=0.9801902174949646
# Bounding box: startX=157, startY=117, endX=248, endY=240
# Face shape: (123, 91, 3)
# Detection 0: confidence=0.980190098285675
# Bounding box: startX=157, startY=117, endX=248, endY=240
# Face shape: (123, 91, 3)
# Detection 0: confidence=0.9832746386528015
# Bounding box: startX=156, startY=118, endX=247, endY=240
# Face shape: (122, 91, 3)
# Detection 0: confidence=0.9818207621574402
# Bounding box: startX=157, startY=118, endX=247, endY=241
# Face shape: (123, 90, 3)
# Detection 0: confidence=0.9829363822937012
# Bounding box: startX=158, startY=118, endX=247, endY=241
# Face shape: (123, 89, 3)
# Detection 0: confidence=0.964633584022522
# Bounding box: startX=159, startY=116, endX=248, endY=240
# Face shape: (124, 89, 3)
# Detection 0: confidence=0.9741197824478149
# Bounding box: startX=161, startY=119, endX=249, endY=237
# Face shape: (118, 88, 3)
# Detection 0: confidence=0.9755479693412781
# Bounding box: startX=164, startY=118, endX=251, endY=237
# Face shape: (119, 87, 3)
# Detection 0: confidence=0.9762800335884094
# Bounding box: startX=168, startY=117, endX=253, endY=235
# Face shape: (118, 85, 3)
# Detection 0: confidence=0.9740267992019653
# Bounding box: startX=169, startY=117, endX=253, endY=235
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9743115305900574
# Bounding box: startX=169, startY=116, endX=253, endY=235
# Face shape: (119, 84, 3)
# Detection 0: confidence=0.9799908399581909
# Bounding box: startX=169, startY=116, endX=253, endY=234
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.977914035320282
# Bounding box: startX=169, startY=117, endX=253, endY=235
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9777170419692993
# Bounding box: startX=169, startY=117, endX=253, endY=235
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9761084914207458
# Bounding box: startX=169, startY=117, endX=253, endY=234
# Face shape: (117, 84, 3)
# Detection 0: confidence=0.9712708592414856
# Bounding box: startX=169, startY=116, endX=253, endY=234
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9782852530479431
# Bounding box: startX=170, startY=116, endX=253, endY=233
# Face shape: (117, 83, 3)
# Detection 0: confidence=0.974147379398346
# Bounding box: startX=170, startY=117, endX=253, endY=234
# Face shape: (117, 83, 3)
# Detection 0: confidence=0.978420078754425
# Bounding box: startX=169, startY=117, endX=253, endY=234
# Face shape: (117, 84, 3)
# Detection 0: confidence=0.9784050583839417
# Bounding box: startX=169, startY=116, endX=253, endY=234
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9707039594650269
# Bounding box: startX=169, startY=117, endX=253, endY=235
# Face shape: (118, 84, 3)
# Detection 0: confidence=0.9587313532829285
# Bounding box: startX=169, startY=118, endX=254, endY=237
# Face shape: (119, 85, 3)
# Detection 0: confidence=0.980550229549408
# Bounding box: startX=165, startY=119, endX=252, endY=236
# Face shape: (117, 87, 3)
# Detection 0: confidence=0.978188157081604
# Bounding box: startX=162, startY=119, endX=250, endY=238
# Face shape: (119, 88, 3)
# Detection 0: confidence=0.9738479256629944
# Bounding box: startX=162, startY=119, endX=251, endY=238
# Face shape: (119, 89, 3)
# Detection 0: confidence=0.9754443764686584
# Bounding box: startX=162, startY=118, endX=252, endY=237
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9717943072319031
# Bounding box: startX=162, startY=118, endX=251, endY=237
# Face shape: (119, 89, 3)
# Detection 0: confidence=0.9830504059791565
# Bounding box: startX=162, startY=119, endX=251, endY=237
# Face shape: (118, 89, 3)
# Detection 0: confidence=0.9773995876312256
# Bounding box: startX=162, startY=119, endX=251, endY=238
# Face shape: (119, 89, 3)
# Detection 0: confidence=0.9624502658843994
# Bounding box: startX=160, startY=120, endX=250, endY=239
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9777546525001526
# Bounding box: startX=161, startY=118, endX=251, endY=237
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9861496686935425
# Bounding box: startX=160, startY=118, endX=249, endY=233
# Face shape: (115, 89, 3)
# Detection 0: confidence=0.9867066740989685
# Bounding box: startX=159, startY=118, endX=248, endY=235
# Face shape: (117, 89, 3)
# Detection 0: confidence=0.9825589656829834
# Bounding box: startX=157, startY=119, endX=248, endY=235
# Face shape: (116, 91, 3)
# Detection 0: confidence=0.9765099287033081
# Bounding box: startX=158, startY=118, endX=248, endY=236
# Face shape: (118, 90, 3)
# Detection 0: confidence=0.9842787384986877
# Bounding box: startX=158, startY=120, endX=249, endY=236
# Face shape: (116, 91, 3)
# Detection 0: confidence=0.9811326861381531
# Bounding box: startX=158, startY=119, endX=250, endY=238
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.9717046022415161
# Bounding box: startX=159, startY=119, endX=250, endY=238
# Face shape: (119, 91, 3)
# Detection 0: confidence=0.9607754349708557
# Bounding box: startX=160, startY=118, endX=251, endY=238
# Face shape: (120, 91, 3)
# Detection 0: confidence=0.9765164256095886
# Bounding box: startX=162, startY=117, endX=252, endY=237
# Face shape: (120, 90, 3)
# Detection 0: confidence=0.9663177132606506
# Bounding box: startX=161, startY=118, endX=252, endY=239
# Face shape: (121, 91, 3)
# Detection 0: confidence=0.9747933745384216
# Bounding box: startX=160, startY=118, endX=252, endY=238
# Face shape: (120, 92, 3)
# Detection 0: confidence=0.9730169773101807
# Bounding box: startX=160, startY=119, endX=251, endY=238
# Face shape: (119, 91, 3)
# Detection 0: confidence=0.9736835360527039
# Bounding box: startX=161, startY=119, endX=251, endY=238
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.9626256823539734
# Bounding box: startX=160, startY=119, endX=251, endY=239
# Face shape: (120, 91, 3)
# Detection 0: confidence=0.9708192348480225
# Bounding box: startX=158, startY=120, endX=250, endY=239
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.9634369611740112
# Bounding box: startX=158, startY=120, endX=249, endY=239
# Face shape: (119, 91, 3)
# Detection 0: confidence=0.9541753530502319
# Bounding box: startX=160, startY=116, endX=248, endY=240
# Face shape: (124, 88, 3)
# Detection 0: confidence=0.9644218683242798
# Bounding box: startX=159, startY=120, endX=249, endY=239
# Face shape: (119, 90, 3)
# Detection 0: confidence=0.977055549621582
# Bounding box: startX=159, startY=121, endX=249, endY=238
# Face shape: (117, 90, 3)
# Detection 0: confidence=0.9702892899513245
# Bounding box: startX=158, startY=120, endX=250, endY=239
# Face shape: (119, 92, 3)
# Detection 0: confidence=0.9733712673187256
# Bounding box: startX=159, startY=120, endX=250, endY=239
# Face shape: (119, 91, 3)

# %% [markdown]
# # NO Voice

# %%
# loop over the frames from the video stream
while True:
    # grab the frame from the threaded video stream and resize it
    # to have a maximum width of 400 pixels
    frame = vs.read()
    frame = imutils.resize(frame, width=400)

    # detect faces in the frame and determine if they are wearing a
    # face mask or not
    (locs, preds) = detect_and_predict_mask(frame, faceNet, maskNet)

    # loop over the detected face locations and their corresponding
    # locations
    for (box, pred) in zip(locs, preds):
        # unpack the bounding box and predictions
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred

        # determine the class label and color we'll use to draw
        # the bounding box and text
        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

        # include the probability in the label
        #label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)
        
        # display the label and bounding box rectangle on the output
        # frame
        if(label=="Mask"):    
            cv2.putText(frame,"Mask: You are allowed", (startX, startY - 10),
            cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
            cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)
        elif(label=="No Mask"):
            lab="No Mask: You are not allowed"
            cv2.putText(frame, lab, (startX, startY - 10),
            cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
            cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

    # show the output frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF

    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break

# do a bit of cleanup
cv2.destroyAllWindows()

vs.release()
# Out:
# Detection 0: confidence=0.999160885810852
# Bounding box: startX=138, startY=134, endX=199, endY=209
# Face shape: (75, 61, 3)
# Detection 0: confidence=0.9991210103034973
# Bounding box: startX=138, startY=134, endX=198, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9988546371459961
# Bounding box: startX=139, startY=134, endX=198, endY=210
# Face shape: (76, 59, 3)
# Detection 0: confidence=0.9982299208641052
# Bounding box: startX=139, startY=134, endX=199, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9979614019393921
# Bounding box: startX=139, startY=134, endX=199, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.99820876121521
# Bounding box: startX=139, startY=134, endX=199, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9986454844474792
# Bounding box: startX=139, startY=134, endX=199, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9987025260925293
# Bounding box: startX=139, startY=134, endX=199, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9987950325012207
# Bounding box: startX=138, startY=134, endX=199, endY=210
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9991256594657898
# Bounding box: startX=138, startY=134, endX=198, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9994055032730103
# Bounding box: startX=137, startY=134, endX=198, endY=210
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9990546107292175
# Bounding box: startX=138, startY=133, endX=198, endY=210
# Face shape: (77, 60, 3)
# Detection 0: confidence=0.9990070462226868
# Bounding box: startX=138, startY=134, endX=198, endY=210
# Face shape: (76, 60, 3)
# Detection 0: confidence=0.9987824559211731
# Bounding box: startX=138, startY=134, endX=199, endY=210
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9987840056419373
# Bounding box: startX=138, startY=134, endX=199, endY=210
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9986200332641602
# Bounding box: startX=138, startY=133, endX=200, endY=210
# Face shape: (77, 62, 3)
# Detection 0: confidence=0.9965227842330933
# Bounding box: startX=140, startY=132, endX=201, endY=210
# Face shape: (78, 61, 3)
# Detection 0: confidence=0.9988928437232971
# Bounding box: startX=141, startY=132, endX=203, endY=210
# Face shape: (78, 62, 3)
# Detection 0: confidence=0.9989240765571594
# Bounding box: startX=141, startY=132, endX=204, endY=210
# Face shape: (78, 63, 3)
# Detection 0: confidence=0.9942610263824463
# Bounding box: startX=155, startY=133, endX=227, endY=224
# Face shape: (91, 72, 3)
# Detection 0: confidence=0.9970088601112366
# Bounding box: startX=165, startY=127, endX=235, endY=223
# Face shape: (96, 70, 3)
# Detection 0: confidence=0.9939454197883606
# Bounding box: startX=170, startY=125, endX=245, endY=223
# Face shape: (98, 75, 3)
# Detection 0: confidence=0.9986005425453186
# Bounding box: startX=184, startY=114, endX=263, endY=210
# Face shape: (96, 79, 3)
# Detection 0: confidence=0.9957947731018066
# Bounding box: startX=196, startY=112, endX=268, endY=210
# Face shape: (98, 72, 3)
# Detection 0: confidence=0.9950318336486816
# Bounding box: startX=198, startY=106, endX=274, endY=207
# Face shape: (101, 76, 3)
# Detection 0: confidence=0.9971803426742554
# Bounding box: startX=202, startY=106, endX=275, endY=206
# Face shape: (100, 73, 3)
# Detection 0: confidence=0.9960600733757019
# Bounding box: startX=200, startY=108, endX=274, endY=209
# Face shape: (101, 74, 3)
# Detection 0: confidence=0.9936161041259766
# Bounding box: startX=199, startY=109, endX=270, endY=205
# Face shape: (96, 71, 3)
# Detection 0: confidence=0.999030351638794
# Bounding box: startX=197, startY=110, endX=269, endY=203
# Face shape: (93, 72, 3)
# Detection 0: confidence=0.9999399185180664
# Bounding box: startX=192, startY=109, endX=263, endY=201
# Face shape: (92, 71, 3)
# Detection 0: confidence=0.9999783039093018
# Bounding box: startX=191, startY=110, endX=259, endY=200
# Face shape: (90, 68, 3)
# Detection 0: confidence=0.9999904632568359
# Bounding box: startX=192, startY=111, endX=256, endY=199
# Face shape: (88, 64, 3)
# Detection 0: confidence=0.9999891519546509
# Bounding box: startX=193, startY=111, endX=257, endY=197
# Face shape: (86, 64, 3)
# Detection 0: confidence=0.9999837875366211
# Bounding box: startX=192, startY=111, endX=257, endY=195
# Face shape: (84, 65, 3)
# Detection 0: confidence=0.9999867677688599
# Bounding box: startX=192, startY=110, endX=258, endY=195
# Face shape: (85, 66, 3)
# Detection 0: confidence=0.9999865293502808
# Bounding box: startX=192, startY=110, endX=258, endY=195
# Face shape: (85, 66, 3)
# Detection 0: confidence=0.9999861717224121
# Bounding box: startX=193, startY=110, endX=257, endY=194
# Face shape: (84, 64, 3)
# Detection 0: confidence=0.9999874830245972
# Bounding box: startX=193, startY=110, endX=258, endY=194
# Face shape: (84, 65, 3)
# Detection 0: confidence=0.9999892711639404
# Bounding box: startX=193, startY=110, endX=258, endY=194
# Face shape: (84, 65, 3)
# Detection 0: confidence=0.9999905824661255
# Bounding box: startX=193, startY=110, endX=258, endY=195
# Face shape: (85, 65, 3)
# Detection 0: confidence=0.9999881982803345
# Bounding box: startX=193, startY=109, endX=258, endY=194
# Face shape: (85, 65, 3)
# Detection 0: confidence=0.9999854564666748
# Bounding box: startX=192, startY=110, endX=258, endY=197
# Face shape: (87, 66, 3)
# Detection 0: confidence=0.9999799728393555
# Bounding box: startX=191, startY=110, endX=258, endY=198
# Face shape: (88, 67, 3)
# Detection 0: confidence=0.9999722242355347
# Bounding box: startX=191, startY=111, endX=259, endY=198
# Face shape: (87, 68, 3)
# Detection 0: confidence=0.9996894598007202
# Bounding box: startX=197, startY=114, endX=265, endY=203
# Face shape: (89, 68, 3)
# Detection 0: confidence=0.9997168183326721
# Bounding box: startX=197, startY=117, endX=266, endY=203
# Face shape: (86, 69, 3)
# Detection 0: confidence=0.9999681711196899
# Bounding box: startX=196, startY=119, endX=264, endY=205
# Face shape: (86, 68, 3)
# Detection 0: confidence=0.9999860525131226
# Bounding box: startX=196, startY=122, endX=262, endY=208
# Face shape: (86, 66, 3)
# Detection 0: confidence=0.9997854828834534
# Bounding box: startX=198, startY=123, endX=265, endY=209
# Face shape: (86, 67, 3)
# Detection 0: confidence=0.9993352293968201
# Bounding box: startX=216, startY=125, endX=274, endY=208
# Face shape: (83, 58, 3)
# Detection 0: confidence=0.9962517619132996
# Bounding box: startX=209, startY=113, endX=280, endY=210
# Face shape: (97, 71, 3)
# Detection 0: confidence=0.9888206720352173
# Bounding box: startX=199, startY=104, endX=274, endY=207
# Face shape: (103, 75, 3)
# Detection 0: confidence=0.9912886619567871
# Bounding box: startX=192, startY=99, endX=278, endY=214
# Face shape: (115, 86, 3)
# Detection 0: confidence=0.991560161113739
# Bounding box: startX=194, startY=100, endX=280, endY=220
# Face shape: (120, 86, 3)
# Detection 0: confidence=0.9892007112503052
# Bounding box: startX=195, startY=102, endX=280, endY=222
# Face shape: (120, 85, 3)
# Detection 0: confidence=0.9851306080818176
# Bounding box: startX=194, startY=102, endX=280, endY=219
# Face shape: (117, 86, 3)
# Detection 0: confidence=0.9896098375320435
# Bounding box: startX=193, startY=101, endX=278, endY=217
# Face shape: (116, 85, 3)
# Detection 0: confidence=0.9931555390357971
# Bounding box: startX=192, startY=101, endX=277, endY=215
# Face shape: (114, 85, 3)
# Detection 0: confidence=0.9903566241264343
# Bounding box: startX=193, startY=101, endX=278, endY=216
# Face shape: (115, 85, 3)
# Detection 0: confidence=0.996464729309082
# Bounding box: startX=194, startY=103, endX=281, endY=227
# Face shape: (124, 87, 3)
# Detection 0: confidence=0.9993605017662048
# Bounding box: startX=194, startY=105, endX=285, endY=233
# Face shape: (128, 91, 3)
# Detection 0: confidence=0.9998602867126465
# Bounding box: startX=194, startY=108, endX=293, endY=240
# Face shape: (132, 99, 3)
# Detection 0: confidence=0.999897837638855
# Bounding box: startX=194, startY=112, endX=296, endY=250
# Face shape: (138, 102, 3)
# Detection 0: confidence=0.9999347925186157
# Bounding box: startX=193, startY=114, endX=295, endY=255
# Face shape: (141, 102, 3)
# Detection 0: confidence=0.9999483823776245
# Bounding box: startX=191, startY=115, endX=293, endY=253
# Face shape: (138, 102, 3)
# Detection 0: confidence=0.9999666213989258
# Bounding box: startX=190, startY=114, endX=291, endY=252
# Face shape: (138, 101, 3)
# Detection 0: confidence=0.9999704360961914
# Bounding box: startX=189, startY=116, endX=291, endY=253
# Face shape: (137, 102, 3)
# Detection 0: confidence=0.9999723434448242
# Bounding box: startX=189, startY=116, endX=291, endY=254
# Face shape: (138, 102, 3)
# Detection 0: confidence=0.9999805688858032
# Bounding box: startX=188, startY=115, endX=290, endY=254
# Face shape: (139, 102, 3)
# Detection 0: confidence=0.9999808073043823
# Bounding box: startX=188, startY=113, endX=289, endY=249
# Face shape: (136, 101, 3)
# Detection 0: confidence=0.9999850988388062
# Bounding box: startX=187, startY=113, endX=287, endY=249
# Face shape: (136, 100, 3)
# Detection 0: confidence=0.9999879598617554
# Bounding box: startX=187, startY=112, endX=287, endY=249
# Face shape: (137, 100, 3)
# Detection 0: confidence=0.9999867677688599
# Bounding box: startX=187, startY=112, endX=287, endY=248
# Face shape: (136, 100, 3)
# Detection 0: confidence=0.9999864101409912
# Bounding box: startX=186, startY=112, endX=286, endY=249
# Face shape: (137, 100, 3)
# Detection 0: confidence=0.9999837875366211
# Bounding box: startX=186, startY=111, endX=286, endY=247
# Face shape: (136, 100, 3)
# Detection 0: confidence=0.9999834299087524
# Bounding box: startX=187, startY=109, endX=285, endY=245
# Face shape: (136, 98, 3)
# Detection 0: confidence=0.9999815225601196
# Bounding box: startX=185, startY=104, endX=283, endY=239
# Face shape: (135, 98, 3)
# Detection 0: confidence=0.998806357383728
# Bounding box: startX=185, startY=98, endX=276, endY=224
# Face shape: (126, 91, 3)
# Detection 0: confidence=0.9958873391151428
# Bounding box: startX=189, startY=102, endX=267, endY=207
# Face shape: (105, 78, 3)
# Detection 0: confidence=0.9996082186698914
# Bounding box: startX=188, startY=106, endX=261, endY=201
# Face shape: (95, 73, 3)
# Detection 0: confidence=0.9994138479232788
# Bounding box: startX=184, startY=116, endX=250, endY=206
# Face shape: (90, 66, 3)
# Detection 0: confidence=0.9998384714126587
# Bounding box: startX=179, startY=126, endX=238, endY=205
# Face shape: (79, 59, 3)
# Detection 0: confidence=0.9999767541885376
# Bounding box: startX=175, startY=126, endX=231, endY=206
# Face shape: (80, 56, 3)
# Detection 0: confidence=0.9999727010726929
# Bounding box: startX=170, startY=126, endX=226, endY=203
# Face shape: (77, 56, 3)
# Detection 0: confidence=0.9911959171295166
# Bounding box: startX=164, startY=126, endX=220, endY=204
# Face shape: (78, 56, 3)
# Detection 0: confidence=0.9989033937454224
# Bounding box: startX=158, startY=127, endX=217, endY=207
# Face shape: (80, 59, 3)
# Detection 0: confidence=0.9943017959594727
# Bounding box: startX=162, startY=128, endX=217, endY=208
# Face shape: (80, 55, 3)
# Detection 0: confidence=0.9901202917098999
# Bounding box: startX=164, startY=128, endX=217, endY=205
# Face shape: (77, 53, 3)
# Detection 0: confidence=0.988909900188446
# Bounding box: startX=164, startY=128, endX=217, endY=204
# Face shape: (76, 53, 3)
# Detection 0: confidence=0.9955753087997437
# Bounding box: startX=162, startY=128, endX=216, endY=204
# Face shape: (76, 54, 3)
# Detection 0: confidence=0.99921715259552
# Bounding box: startX=159, startY=126, endX=217, endY=201
# Face shape: (75, 58, 3)
# Detection 0: confidence=0.9998262524604797
# Bounding box: startX=159, startY=126, endX=216, endY=200
# Face shape: (74, 57, 3)
# Detection 0: confidence=0.9999053478240967
# Bounding box: startX=156, startY=126, endX=213, endY=200
# Face shape: (74, 57, 3)
# Detection 0: confidence=0.9996193647384644
# Bounding box: startX=157, startY=126, endX=213, endY=198
# Face shape: (72, 56, 3)
# Detection 0: confidence=0.9956223368644714
# Bounding box: startX=161, startY=126, endX=215, endY=196
# Face shape: (70, 54, 3)
# Detection 0: confidence=0.9914865493774414
# Bounding box: startX=162, startY=126, endX=216, endY=196
# Face shape: (70, 54, 3)
# Detection 0: confidence=0.9939042925834656
# Bounding box: startX=161, startY=126, endX=215, endY=195
# Face shape: (69, 54, 3)
# Detection 0: confidence=0.9977198243141174
# Bounding box: startX=160, startY=127, endX=214, endY=196
# Face shape: (69, 54, 3)
# Detection 0: confidence=0.9848698377609253
# Bounding box: startX=159, startY=124, endX=214, endY=192
# Face shape: (68, 55, 3)
# Detection 0: confidence=0.9968108534812927
# Bounding box: startX=160, startY=125, endX=213, endY=193
# Face shape: (68, 53, 3)
# Detection 0: confidence=0.9965763688087463
# Bounding box: startX=160, startY=124, endX=214, endY=194
# Face shape: (70, 54, 3)
# Detection 0: confidence=0.995042085647583
# Bounding box: startX=159, startY=126, endX=215, endY=194
# Face shape: (68, 56, 3)
# Detection 0: confidence=0.989316463470459
# Bounding box: startX=156, startY=124, endX=217, endY=203
# Face shape: (79, 61, 3)
# Detection 0: confidence=0.9978944659233093
# Bounding box: startX=153, startY=124, endX=216, endY=205
# Face shape: (81, 63, 3)
# Detection 0: confidence=0.9944688081741333
# Bounding box: startX=152, startY=126, endX=216, endY=199
# Face shape: (73, 64, 3)
# Detection 0: confidence=0.9917001128196716
# Bounding box: startX=151, startY=125, endX=217, endY=206
# Face shape: (81, 66, 3)
# Detection 0: confidence=0.9996590614318848
# Bounding box: startX=154, startY=126, endX=215, endY=201
# Face shape: (75, 61, 3)
# Detection 0: confidence=0.9994316697120667
# Bounding box: startX=153, startY=125, endX=216, endY=201
# Face shape: (76, 63, 3)
# Detection 0: confidence=0.9944313168525696
# Bounding box: startX=155, startY=123, endX=217, endY=202
# Face shape: (79, 62, 3)
# Detection 0: confidence=0.9969209432601929
# Bounding box: startX=153, startY=125, endX=215, endY=201
# Face shape: (76, 62, 3)
# Detection 0: confidence=0.9987757802009583
# Bounding box: startX=153, startY=126, endX=216, endY=200
# Face shape: (74, 63, 3)
# Detection 0: confidence=0.9993240833282471
# Bounding box: startX=153, startY=126, endX=214, endY=201
# Face shape: (75, 61, 3)
# Detection 0: confidence=0.9997937083244324
# Bounding box: startX=153, startY=127, endX=213, endY=204
# Face shape: (77, 60, 3)
# Detection 0: confidence=0.9999464750289917
# Bounding box: startX=153, startY=126, endX=213, endY=207
# Face shape: (81, 60, 3)
# Detection 0: confidence=0.9999203681945801
# Bounding box: startX=156, startY=128, endX=215, endY=209
# Face shape: (81, 59, 3)
# Detection 0: confidence=0.9996942281723022
# Bounding box: startX=155, startY=125, endX=217, endY=209
# Face shape: (84, 62, 3)
# Detection 0: confidence=0.9943267703056335
# Bounding box: startX=156, startY=122, endX=217, endY=203
# Face shape: (81, 61, 3)
# Detection 0: confidence=0.7795366048812866
# Bounding box: startX=159, startY=120, endX=219, endY=198
# Face shape: (78, 60, 3)
# Detection 0: confidence=0.9427542090415955
# Bounding box: startX=156, startY=124, endX=218, endY=191
# Face shape: (67, 62, 3)
# Detection 0: confidence=0.9899750351905823
# Bounding box: startX=156, startY=127, endX=217, endY=194
# Face shape: (67, 61, 3)
# Detection 0: confidence=0.9988381266593933
# Bounding box: startX=155, startY=126, endX=218, endY=203
# Face shape: (77, 63, 3)
# Detection 0: confidence=0.9998688697814941
# Bounding box: startX=153, startY=127, endX=214, endY=207
# Face shape: (80, 61, 3)
# Detection 0: confidence=0.9997422099113464
# Bounding box: startX=153, startY=127, endX=214, endY=209
# Face shape: (82, 61, 3)
# Detection 0: confidence=0.9997847676277161
# Bounding box: startX=153, startY=126, endX=214, endY=208
# Face shape: (82, 61, 3)
# Detection 0: confidence=0.9997078776359558
# Bounding box: startX=153, startY=127, endX=215, endY=210
# Face shape: (83, 62, 3)
# Detection 0: confidence=0.9997575879096985
# Bounding box: startX=154, startY=126, endX=215, endY=210
# Face shape: (84, 61, 3)
# Detection 0: confidence=0.9986181259155273
# Bounding box: startX=154, startY=125, endX=217, endY=210
# Face shape: (85, 63, 3)
# Detection 0: confidence=0.9989168643951416
# Bounding box: startX=155, startY=125, endX=216, endY=211
# Face shape: (86, 61, 3)
# Detection 0: confidence=0.9970571994781494
# Bounding box: startX=154, startY=125, endX=217, endY=208
# Face shape: (83, 63, 3)
# Detection 0: confidence=0.9587966799736023
# Bounding box: startX=156, startY=126, endX=221, endY=206
# Face shape: (80, 65, 3)
# Detection 0: confidence=0.9554241895675659
# Bounding box: startX=156, startY=124, endX=221, endY=212
# Face shape: (88, 65, 3)
# Detection 0: confidence=0.9727464318275452
# Bounding box: startX=157, startY=122, endX=223, endY=208
# Face shape: (86, 66, 3)
# Detection 0: confidence=0.9674047827720642
# Bounding box: startX=156, startY=122, endX=218, endY=204
# Face shape: (82, 62, 3)
# Detection 0: confidence=0.9331687092781067
# Bounding box: startX=162, startY=122, endX=220, endY=199
# Face shape: (77, 58, 3)
# Detection 0: confidence=0.9784107208251953
# Bounding box: startX=155, startY=124, endX=216, endY=198
# Face shape: (74, 61, 3)
# Detection 0: confidence=0.9882110953330994
# Bounding box: startX=150, startY=124, endX=215, endY=199
# Face shape: (75, 65, 3)
# Detection 0: confidence=0.9867488145828247
# Bounding box: startX=147, startY=125, endX=208, endY=201
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9987748265266418
# Bounding box: startX=146, startY=125, endX=207, endY=201
# Face shape: (76, 61, 3)
# Detection 0: confidence=0.9999171495437622
# Bounding box: startX=149, startY=125, endX=209, endY=199
# Face shape: (74, 60, 3)
# Detection 0: confidence=0.9997894167900085
# Bounding box: startX=157, startY=127, endX=211, endY=199
# Face shape: (72, 54, 3)
# Detection 0: confidence=0.9978899359703064
# Bounding box: startX=161, startY=127, endX=215, endY=198
# Face shape: (71, 54, 3)
# Detection 0: confidence=0.9973552227020264
# Bounding box: startX=161, startY=128, endX=215, endY=198
# Face shape: (70, 54, 3)
# Detection 0: confidence=0.9995535016059875
# Bounding box: startX=160, startY=128, endX=215, endY=199
# Face shape: (71, 55, 3)
# Detection 0: confidence=0.9999328851699829
# Bounding box: startX=156, startY=128, endX=212, endY=200
# Face shape: (72, 56, 3)
# Detection 0: confidence=0.9999399185180664
# Bounding box: startX=152, startY=128, endX=209, endY=201
# Face shape: (73, 57, 3)
# Detection 0: confidence=0.9999074935913086
# Bounding box: startX=149, startY=128, endX=208, endY=202
# Face shape: (74, 59, 3)
# Detection 0: confidence=0.9998559951782227
# Bounding box: startX=148, startY=128, endX=208, endY=203
# Face shape: (75, 60, 3)
# Detection 0: confidence=0.9998844861984253
# Bounding box: startX=148, startY=128, endX=208, endY=203
# Face shape: (75, 60, 3)
# Detection 0: confidence=0.9998136162757874
# Bounding box: startX=148, startY=128, endX=206, endY=204
# Face shape: (76, 58, 3)
# Detection 0: confidence=0.9997548460960388
# Bounding box: startX=148, startY=128, endX=206, endY=204
# Face shape: (76, 58, 3)
# Detection 0: confidence=0.9997128844261169
# Bounding box: startX=148, startY=129, endX=206, endY=203
# Face shape: (74, 58, 3)
# Detection 0: confidence=0.9996544122695923
# Bounding box: startX=147, startY=128, endX=205, endY=203
# Face shape: (75, 58, 3)
# Detection 0: confidence=0.9996567964553833
# Bounding box: startX=146, startY=128, endX=206, endY=203
# Face shape: (75, 60, 3)
# Detection 0: confidence=0.9996844530105591
# Bounding box: startX=146, startY=128, endX=206, endY=203
# Face shape: (75, 60, 3)
# Detection 0: confidence=0.99968421459198
# Bounding box: startX=146, startY=128, endX=205, endY=203
# Face shape: (75, 59, 3)
# Detection 0: confidence=0.9997594952583313
# Bounding box: startX=146, startY=128, endX=205, endY=203
# Face shape: (75, 59, 3)
# Detection 0: confidence=0.9997949004173279
# Bounding box: startX=146, startY=129, endX=205, endY=203
# Face shape: (74, 59, 3)
# Detection 0: confidence=0.9998669624328613
# Bounding box: startX=146, startY=129, endX=205, endY=204
# Face shape: (75, 59, 3)
# Detection 0: confidence=0.9998284578323364
# Bounding box: startX=145, startY=128, endX=204, endY=204
# Face shape: (76, 59, 3)
# Detection 0: confidence=0.9991883635520935
# Bounding box: startX=143, startY=128, endX=202, endY=203
# Face shape: (75, 59, 3)
# Detection 0: confidence=0.998015284538269
# Bounding box: startX=140, startY=127, endX=198, endY=203
# Face shape: (76, 58, 3)
# Detection 0: confidence=0.9998923540115356
# Bounding box: startX=136, startY=126, endX=194, endY=203
# Face shape: (77, 58, 3)
# Detection 0: confidence=0.9999480247497559
# Bounding box: startX=127, startY=124, endX=189, endY=206
# Face shape: (82, 62, 3)
# Detection 0: confidence=0.9997468590736389
# Bounding box: startX=117, startY=124, endX=184, endY=208
# Face shape: (84, 67, 3)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10296\1338809681.py in <module>
#      48 cv2.destroyAllWindows()
#      49
# ---> 50 vs.release()
#
# AttributeError: 'WebcamVideoStream' object has no attribute 'release'
